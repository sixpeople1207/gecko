# %%
import requests 
from datetime import datetime
from datetime import date
import time
import sqlite3


path = './CoinData.db'

def get_histroy(name, fromDate, toDate):
    url = f'https://api.coingecko.com/api/v3/coins/{name}/market_chart/range?vs_currency=usd&from={fromDate}&to={toDate}&precision=0'
    print(url)
    response = requests.get(url).json();
    return response

def get_list():
    url = 'https://api.coingecko.com/api/v3/coins/markets/?vs_currency=usd&order=market_cap_desc&per_page=300&page=1&sparkline=false'
    response = requests.get(url).json()
    return response

def DBInIt(path):
    con = sqlite3.connect(path)
    cur = con.cursor()
    cur.execute("CREATE TABLE CoinList(Rank text,Name text,ath text);")
    cur.execute("CREATE TABLE CoinHistory(Name text, Date DateTime,Price int);")

def DBDRopTable(path, tableName):
    con = sqlite3.connect(path)
    cur = con.cursor()
    cur.execute(f"drop table {tableName}")

#DBDRopTable(path, 'CoinList')
#DBDRopTable(path, 'CoinHistory')
DBInIt(path)

# %%
# _init('./CoinGecKoData.db')
nameList = get_list()
nameList
# Out:
# [{'id': 'bitcoin',
#   'symbol': 'btc',
#   'name': 'Bitcoin',
#   'image': 'https://assets.coingecko.com/coins/images/1/large/bitcoin.png?1547033579',
#   'current_price': 29444,
#   'market_cap': 572483039226,
#   'market_cap_rank': 1,
#   'fully_diluted_valuation': 618058210174,
#   'total_volume': 14424466642,
#   'high_24h': 29578,
#   'low_24h': 28755,
#   'price_change_24h': 507.72,
#   'price_change_percentage_24h': 1.7546,
#   'market_cap_change_24h': 9370659981,
#   'market_cap_change_percentage_24h': 1.66408,
#   'circulating_supply': 19451475.0,
#   'total_supply': 21000000.0,
#   'max_supply': 21000000.0,
#   'ath': 69045,
#   'ath_change_percentage': -57.3548,
#   'ath_date': '2021-11-10T14:24:11.849Z',
#   'atl': 67.81,
#   'atl_change_percentage': 43322.38155,
#   'atl_date': '2013-07-06T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2023-08-08T15:17:47.942Z'},
#  {'id': 'ethereum',
#   'symbol': 'eth',
#   'name': 'Ethereum',
# ...

# %%
def DBInsert_CoinList(path, list):
    con = sqlite3.connect(path)
    cur = con.cursor()
    for li in list:
        #print("INSERT INTO CoinList Values('"+li[0]['market_cap_rank']+"','"+li[0]['id']+"','"+li[0]['ath']+"');")
        cur.execute(f"INSERT INTO CoinList Values('{li['market_cap_rank']}','{li['id']}','{li['ath']}');")
    con.commit()
    con.close()


DBInsert_CoinList(path, nameList)

# %%
# res[0]['id']
len(nameList)
# Out:
# 250

# %%
toDate = time.mktime(datetime.today().timetuple())
fromDate = time.mktime(date(2020, 11, 5).timetuple())

history = get_histroy('bitcoin', str(fromDate), str(toDate))
dd = history['prices'][0][1]
type(dd)
# Out:
# https://api.coingecko.com/api/v3/coins/bitcoin/market_chart/range?vs_currency=usd&from=1604502000.0&to=1691507878.0&precision=0
# int

# %%
def DBInsert_Prices(path, nameList):
    con = sqlite3.connect(path)
    cur = con.cursor()
    for name in nameList:
        name = nameList[0]['id']
        history=get_histroy(name, str(fromDate), str(toDate))
        time.sleep(10)
        for i in range(len(history['prices'])):
            date = datetime.fromtimestamp(history['prices'][i][0]/1000)
            cur.execute(
                f"INSERT INTO CoinHistory Values('{name}', '{date}','{history['prices'][0][1]}');")
            con.commit()
    con.close()

DBInsert_Prices(path, nameList)
# Out:
# https://api.coingecko.com/api/v3/coins/bitcoin/market_chart/range?vs_currency=usd&from=1604502000.0&to=1691507878.0&precision=0
# https://api.coingecko.com/api/v3/coins/bitcoin/market_chart/range?vs_currency=usd&from=1604502000.0&to=1691507878.0&precision=0
# https://api.coingecko.com/api/v3/coins/bitcoin/market_chart/range?vs_currency=usd&from=1604502000.0&to=1691507878.0&precision=0
# https://api.coingecko.com/api/v3/coins/bitcoin/market_chart/range?vs_currency=usd&from=1604502000.0&to=1691507878.0&precision=0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-142-2f70e5ac69b9> in <module>
#      14
#      15
# ---> 16 DBInsert_Prices(path, nameList)
#
# <ipython-input-142-2f70e5ac69b9> in DBInsert_Prices(path, nameList)
#       5         name = nameList[0]['id']
#       6         history=get_histroy(name, str(fromDate), str(toDate))
# ...
